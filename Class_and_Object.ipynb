# %% [markdown]
# <a href="https://colab.research.google.com/github/slreddy01/code-usecases/blob/main/Class_and_Object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function

def display(name):
  print("hello",name)
  return

#main
display("sam")
# Out:
# hello sam

# %% [markdown]
# Objects
#
# when we combine data and its functionality we call them as objects. Class and objects are main aspects
#
#
# the above ones are called Procedural oriented techniques. Functions are the main aspects

# %% [markdown]
# Object ⁉
#
# It is collection of data and its functionality, Ex: car,ball,house
#
# Class
#
# it is a blue print of object. Using class we can create many objects
#
# Ex: House is a object and sketch of the house is class.
# Class is a template to create an object.
#
# To create class we use the keyword Class followed by classname
#
# Class person:
#   pass

# %%
class person:
  pass# means an empty class bcoz data and functionality are not present in this class

#main
p=person()
# p is the objectname
#person is the name of the class
# classname and set of paranthesis is used to create an object p
print(p)

# data is called as fields and functionality called as methods in Classes

# %% [markdown]
# Class Methods
#
# class person:
#   def name(paramlist)
#
#   # here name is the method means the functionality which we define in class is a method
#   # it looks like a normal function but there is a difference between method and normal function like in the paramater list which we define in paranthesis. Most of the programmers define the parameter with name starts as self and then define parameters, may not be always self. It is not a keyword just to differentiate between method and normal function we will add self in paranthesis of method name
#
#
# class person:
#   def display(self):
#     print("hello")
#
# #objectname: person1
#
# person1= person()
# person1.display() #how to access method in class
#
# objectname.methodname()
# no need to define parameters inside the methods, methodname we are calling so it is nothing but self
#
# In python no need to pass the objectname externally , it is treated as display(person1), which is passed to the method
#
#
#
#
# 1.   List item
# 2.   List item
#
#
#
#
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# Init Method----------used to initilazie the
#
#
# class person:
#   def_int_(self,name):
#     self.name=name
#   def display(self):
#     print("hello",self.name)
#
# person1=person("amul")
# person1.display()
#
# # no need to call the initialisation method bcoz when an object is created the method is created automatically
#
# # 2 methods are using in the above code
# _init_()
# display()

# %%
class person:
  def __init__(self,name):
    self.name=name
  def display(self):
    print("hello",self.name)

person1=person("amul")
person1.display()
# Out:
# hello amul

# %% [markdown]
# What is the use of the self parameter?
#
# bcoz it differentiate between instance variable and local variables.
#
#
# Instance Variables:
# Variable belongs to an object.
# self.name
# self refers to an object, in our example object is nothing but person1.
#
# so it is nothing but person1.name
#
# and self.name == object.name
# and name == local variable
#
# main difference between local variable and instance variable is using the keyword self

# %%
class person():
  def __init__(self,name1):
    self.name1=name1
    name1 ="john"
    print(name1)
  def display(self):
    print("hello",self.name1)
#person1 =person("amul")
#person1.display()
# we can create a single line like below instead of the above 2 lines
person("amul").display()
# Out:
# john
# hello amul

# %% [markdown]
# fundamental features of OOPs(Object oriented programming techniques)
#
# 1.Inheritance
#
# 2.Encapsulation
#
# 3.Polymorphism **bold text**
