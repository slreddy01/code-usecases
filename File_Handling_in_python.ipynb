# %% [markdown]
# <a href="https://colab.research.google.com/github/slreddy01/code-usecases/blob/main/File_Handling_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to open a text file in python usse keyword open
# open(filename, mode)
# 3 modes - write,append and read mode
# if file is already present we can open in any mode
# if the file is not present ,we can open in write or append mode, so that we can create

textfile = open("text.txt",'w')

# %% [markdown]
# To create a new file in Python, use the open() method, with one of the following parameters:
#
# open() will take 2 parameters(filename,mode)
#
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# "x" - Create - Creates the specified file, returns an error if the file exists
#
#
# Write to an Existing File
# To write to an existing file, you must add a parameter to the open() function:
#
# "a" - Append - will append to the end of the file
#
# "w" - Write - will overwrite any existing content
#
# Open the file "demofile.txt" and append content to the file:
#
# with open("demofile.txt", "a") as f:
#   f.write("Now the file has more content!")
#
# #open and read the file after the appending:
# with open("demofile.txt") as f:
#   print(f.read())

# %% [markdown]
# import os
# if os.path.exists("demofile.txt"):
#
#   os.remove("demofile.txt")
#
# else:
#
#   print("The file does not exist"):

# %% [markdown]
# #Remove the file "demofile.txt":
#
# import os
# os.remove("demofile.txt")

# %% [markdown]
# Manging Directories in python
#
# when we are defining the directories 1st we have to import OS and make a directory as mkdir
# So always use the command import os and create a path in the initial set up and then mkdir
#
# import os
#
# def create_desktop_file(filename, content=""):
#     """
#     Creates a file on the user's desktop with the given filename and content.
#     """
#     # Get the user's home directory
#     home_dir = os.path.expanduser('~')
#
#
#
# mkdir("c:\\desktop\\foldername")
#
# always we have to provide backslash after each folder
#
# to remove any dir
# rmdir
#
# Manging Directories in python
#
# when we are defining the directories 1st we have to import OS and make a directory as mkdir
# So always use the command import os and create a path in the initial set up and then mkdir
#
# import os
#
# def create_desktop_file(filename, content=""):
#     """
#     Creates a file on the user's desktop with the given filename and content.
#     """
#     # Get the user's home directory
#     home_dir = os.path.expanduser('~')
#
#
#
# mkdir("c:\\desktop\\foldername")
#
# always we have to provide backslash after each folder
#
# to remove any dir
# rmdir
#
# Remove the folder "myfolder":
#
# import os
# os.rmdir("myfolder")

# %% [markdown]
# Exception Handling
#
# This is how to handle errors in python not using manual way
#
# To do any calculations we first need to import math function
